# %%
import pandas as pd
import pickle as pkl
import os

# %%
file = open('DToRemove.pickle','rb')
deletelist = pkl.load(file)
deletelist
# Out:
# ['d17850000',
#  'd13720000',
#  'd17190000',
#  'd18600000',
#  'd13970000',
#  'd14110000',
#  'd16770000',
#  'd14280000',
#  'd16740000',
#  'd17010000',
#  'd14380000',
#  'd18870000',
#  'd17110000',
#  'd20470000',
#  'd19190000',
#  'd19220000',
#  'd19210000',
#  'd19140000',
#  'd18430000',
#  'd20010000',
#  'd13680000',
#  'd15780000',
#  'd19160000',
#  'd15200000',
#  'd19990000',
#  'd16710000',
#  'd19640000',
#  'd19620000',
#  'd19710000',
#  'd16570000',
#  'd20150000',
#  'd19900000',
#  'd15660000',
#  'd16730000',
#  'd17390000',
#  'd19720000',
#  'd19240000',
#  'd19260000',
#  'd19280000',
#  'd15570000',
#  'd15190000',
#  'd20020000',
#  'd18640000',
#  'd19100000',
#  'd18620000',
#  'd20400000',
#  'd22100000',
#  'd18350000',
#  'd16820000',
#  'd15210000',
#  'd19550000',
#  'd19520000',
#  'd19530000',
#  'd19410000',
#  'd16780000',
#  'd16840000',
#  'd13960000',
#  'd17750000',
#  'd15360000',
#  'd22110000',
#  'd20780000',
#  'd17790000',
# ...

# %%
for card in deletelist:
    removecard = str(card)+'.png'
    try:
        os.remove(removecard)
    except:
        break
